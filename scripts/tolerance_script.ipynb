# %%
include("../src/include_file.jl")
# Out:
# extendInitialDataToK (generic function with 1 method)

# %%
# An entropic case

Nx = 50
CFL_factor = 0.5
eq = SaintVenant(bump_zb(), 1e-10)
domain = createUnitInterval(Nx, 0.0, 0.1)
method = createHydrostatic(CFL_factor, Rusanov)
addSource!(eq.source, domain)
u_init = v0_lake_at_rest_perturbated(domain.x, eq.source)

solEnt = optimize_for_entropy(u_init, domain, eq, method; f_tol=1e-5, iterations=100000)#, g_tol=1e-10)#, modifiedDataType=maxK())
plot_solution(solEnt)
# Out:
# sol = optimize((gamma->begin
#                 #= c:\Users\marie\Documents\Cours\3ème_année\Stage\NumericalDiffusion\src\opt_diffusion.jl:362 =#
#                 J(optimFunctional, gamma, u_approx[end - 1], u_approx[end], Nx, dx, dt_vec[end], m_vec, M_vec, equation, domain)
#             end), gamma_init; kwargs...) =  * Status: success
#
#  * Candidate solution
#     Final objective value:     1.000000e+00
#
#  * Found with
#     Algorithm:     Nelder-Mead
#
#  * Convergence measures
#     √(Σ(yᵢ-ȳ)²)/n ≤ 1.0e-08
#
#  * Work counters
#     Seconds run:   0  (vs limit Inf)
#     Iterations:    880
#     f(x) calls:    1557
#
# Maximal diffusion value : -1.0824278175451847e-7

# %%
# An non entropic case # construction the counter example

Nx = 50
CFL_factor = 0.5
eq = SaintVenant(bump_zb(), 1e-10)
method = createHydrostatic(CFL_factor, Rusanov)
boxBounds=[0.0 3;-1.0 1.0]
sourceBounds=[-1.0, 1.0]

sol = iterate_WID(Nx, eq, method; nb_it=1, boxBounds=boxBounds, sourceBounds=sourceBounds)

# Reconstruction of the initial data from the optimization results
u_init, z = extendInitialDataToK(sol, Nx)

domain = createUnitInterval(Nx, 0.0, 0.1)
dt = sol.method.CFL_factor * domain.dx / CFL_cond(sol.equation, u_init) # Timestep given by CFL condition

# Redefining the domain with dt as final time
domain = createUnitInterval(Nx, 0.0, dt)
domain.sourceVec = z

# Solving Saint-Venant for this data
fv_sol = fv_solve(domain, u_init, eq, method)
display(plot_fv_sol(fv_sol, eq, nb_plots=2))
# Out:
# nothing

# %%
# Testing different values for f_tol

solEnt = optimize_for_entropy(u_init, domain, eq, method; f_tol=1e-2, iterations=100000)#, g_tol=1e-10)#, modifiedDataType=maxK())
plot_solution(solEnt)
# Out:
# sol = optimize((gamma->begin
#                 #= c:\Users\marie\Documents\Cours\3ème_année\Stage\NumericalDiffusion\src\opt_diffusion.jl:362 =#
#                 J(optimFunctional, gamma, u_approx[end - 1], u_approx[end], Nx, dx, dt_vec[end], m_vec, M_vec, equation, domain)
#             end), gamma_init; kwargs...) =  * Status: success
#
#  * Candidate solution
#     Final objective value:     1.038002e+00
#
#  * Found with
#     Algorithm:     Nelder-Mead
#
#  * Convergence measures
#     √(Σ(yᵢ-ȳ)²)/n ≤ 1.0e-08
#
#  * Work counters
#     Seconds run:   3  (vs limit Inf)
#     Iterations:    20272
#     f(x) calls:    23229
#
# Maximal diffusion value : 0.11249455729618596

# %%
# Testing different values for f_tol

solEnt = optimize_for_entropy(u_init, domain, eq, method; f_tol=1e-4, iterations=100000)#, g_tol=1e-10)#, modifiedDataType=maxK())
plot_solution(solEnt)
# Out:
# sol = optimize((gamma->begin
#                 #= c:\Users\marie\Documents\Cours\3ème_année\Stage\NumericalDiffusion\src\opt_diffusion.jl:362 =#
#                 J(optimFunctional, gamma, u_approx[end - 1], u_approx[end], Nx, dx, dt_vec[end], m_vec, M_vec, equation, domain)
#             end), gamma_init; kwargs...) =  * Status: success
#
#  * Candidate solution
#     Final objective value:     1.038002e+00
#
#  * Found with
#     Algorithm:     Nelder-Mead
#
#  * Convergence measures
#     √(Σ(yᵢ-ȳ)²)/n ≤ 1.0e-08
#
#  * Work counters
#     Seconds run:   3  (vs limit Inf)
#     Iterations:    20272
#     f(x) calls:    23229
#
# Maximal diffusion value :

# %%
# Testing different values for f_tol

solEnt = optimize_for_entropy(u_init, domain, eq, method; f_tol=1e-16, iterations=100000)#, g_tol=1e-10)#, modifiedDataType=maxK())
plot_solution(solEnt)
# Out:
# sol = optimize((gamma->begin
#                 #= c:\Users\marie\Documents\Cours\3ème_année\Stage\NumericalDiffusion\src\opt_diffusion.jl:362 =#
#                 J(optimFunctional, gamma, u_approx[end - 1], u_approx[end], Nx, dx, dt_vec[end], m_vec, M_vec, equation, domain)
#             end), gamma_init; kwargs...) =  * Status: success
#
#  * Candidate solution
#     Final objective value:     1.038002e+00
#
#  * Found with
#     Algorithm:     Nelder-Mead
#
#  * Convergence measures
#     √(Σ(yᵢ-ȳ)²)/n ≤ 1.0e-08
#
#  * Work counters
#     Seconds run:   3  (vs limit Inf)
#     Iterations:    20272
#     f(x) calls:    23229
#
# Maximal diffusion value : 0.11249455729618596

# %%
# Testing different values for g_tol

solEnt = optimize_for_entropy(u_init, domain, eq, method; g_tol=1e-8, iterations=100000)#, g_tol=1e-10)#, modifiedDataType=maxK())
plot_solution(solEnt)
# Out:
# sol = optimize((gamma->begin
#                 #= c:\Users\marie\Documents\Cours\3ème_année\Stage\NumericalDiffusion\src\opt_diffusion.jl:362 =#
#                 J(optimFunctional, gamma, u_approx[end - 1], u_approx[end], Nx, dx, dt_vec[end], m_vec, M_vec, equation, domain)
#             end), gamma_init; kwargs...) =  * Status: success
#
#  * Candidate solution
#     Final objective value:     1.038002e+00
#
#  * Found with
#     Algorithm:     Nelder-Mead
#
#  * Convergence measures
#     √(Σ(yᵢ-ȳ)²)/n ≤ 1.0e-08
#
#  * Work counters
#     Seconds run:   3  (vs limit Inf)
#     Iterations:    20272
#     f(x) calls:    23229
#
# Maximal diffusion value : 0.11249455729618596

# %%
# Testing different values for g_tol

solEnt = optimize_for_entropy(u_init, domain, eq, method; g_tol=1e-16, iterations=100000)#, g_tol=1e-10)#, modifiedDataType=maxK())
plot_solution(solEnt)
# Out:
# sol = optimize((gamma->begin
#                 #= c:\Users\marie\Documents\Cours\3ème_année\Stage\NumericalDiffusion\src\opt_diffusion.jl:362 =#
#                 J(optimFunctional, gamma, u_approx[end - 1], u_approx[end], Nx, dx, dt_vec[end], m_vec, M_vec, equation, domain)
#             end), gamma_init; kwargs...) =  * Status: failure (reached maximum number of iterations)
#
#  * Candidate solution
#     Final objective value:     1.038002e+00
#
#  * Found with
#     Algorithm:     Nelder-Mead
#
#  * Convergence measures
#     √(Σ(yᵢ-ȳ)²)/n ≰ 1.0e-16
#
#  * Work counters
#     Seconds run:   571  (vs limit Inf)
#     Iterations:    100000
#     f(x) calls:    3930626
#
# Maximal diffusion value : 0.11249695160279316
